# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Leitura

# %%
df = pd.read_csv("Python_M10_support material.csv")

# %% [markdown]
# ## Processamento

# %%
# verificando tipagem dos dados
df.dtypes
# Out:
# id                          int64
# default                     int64
# idade                       int64
# sexo                       object
# dependentes                 int64
# escolaridade               object
# estado_civil               object
# salario_anual              object
# tipo_cartao                object
# meses_de_relacionamento     int64
# qtd_produtos                int64
# iteracoes_12m               int64
# meses_inativo_12m           int64
# limite_credito             object
# valor_transacoes_12m       object
# qtd_transacoes_12m          int64
# dtype: object

# %%
transformar_em_float = ['qtd_transacoes_12m','valor_transacoes_12m']

for col in transformar_em_float:
    # Convertendo para string
    df[col] = df[col].astype(str)
    # substituindo . da casa de milhar por nada
    df[col] = df[col].str.replace(".","")
    # substituindo a vírgula da casa de milhar por ponto
    df[col] = df[col].str.replace(",",".")
    # mudando o tipo para float
    df[col] = df[col].astype("float")

# %%
df.dtypes
# Out:
# id                           int64
# default                      int64
# idade                        int64
# sexo                        object
# dependentes                  int64
# escolaridade                object
# estado_civil                object
# salario_anual               object
# tipo_cartao                 object
# meses_de_relacionamento      int64
# qtd_produtos                 int64
# iteracoes_12m                int64
# meses_inativo_12m            int64
# limite_credito              object
# valor_transacoes_12m       float64
# qtd_transacoes_12m         float64
# dtype: object

# %%
df.head()
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3           na  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
# ### Segmentação de clientes

# %%
# Cores para os setores do gráfico de pizza
cores = ['pink', 'blue']

# %%
df_por_sexo = df.groupby('sexo').agg({'id':'nunique'}).reset_index()

# %%
# Criação do gráfico de pizza
plt.figure(figsize=(8, 6))
plt.pie(df_por_sexo['id'], labels=df_por_sexo['sexo'], colors=cores, autopct='%1.1f%%', startangle=140)
plt.axis('equal')

# título
plt.title('Distribuição de clientes por sexo')

# Mostra o gráfico
plt.show()

# %%
idades = df[['idade']]

# %%
# Criar o histograma
plt.figure(figsize=(8, 6))
plt.hist(idades, bins=10, color='skyblue', edgecolor='black', alpha=0.7)

# Adicionar rótulos e título
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.title('Distribuição de Idades dos Clientes')

# Mostrar o histograma
plt.show()

# %%
df_por_escolaridade = df.groupby('escolaridade').agg({'id':'nunique'}).reset_index()

# %%
# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(df_por_escolaridade['escolaridade'], df_por_escolaridade['id'], color='grey')

# Adicionar rótulos e título
plt.xlabel('Escolaridade')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Clientes por Escolaridade')

# Rotacionar os rótulos no eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Mostrar o gráfico de barras
plt.tight_layout()
plt.show()

# %%
df_por_salario = df.groupby('salario_anual').agg({'id':'nunique'}).reset_index()

# %%
# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(df_por_salario['salario_anual'], df_por_salario['id'], color='green')

# Adicionar rótulos e título
plt.xlabel('Salário Anual')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Clientes por Salário Anual')

# Rotacionar os rótulos no eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Mostrar o gráfico de barras
plt.tight_layout()
plt.show()

# %%
df.groupby(['tipo_cartao']).agg({'meses_de_relacionamento':'mean'}).reset_index()
# Out:
#   tipo_cartao  meses_de_relacionamento
# 0        blue                35.960682
# 1        gold                35.525862
# 2    platinum                36.250000
# 3      silver                35.452252

# %%
df.groupby(['tipo_cartao']).agg({'idade':'mean'}).reset_index()
# Out:
#   tipo_cartao      idade
# 0        blue  46.372404
# 1        gold  45.439655
# 2    platinum  47.500000
# 3      silver  45.679279

# %%
df.groupby(['tipo_cartao']).agg({'qtd_transacoes_12m':'mean'}).reset_index()
# Out:
#   tipo_cartao  qtd_transacoes_12m
# 0        blue          640.281899
# 1        gold          815.172414
# 2    platinum          869.500000
# 3      silver          747.009009
